# %%
import pandas as pd
import json

# %%
with open('JSON file/match_info.json') as f:
    data = json.load(f)
data
# Out:
# {'Team 1': {'0': 'India',
#   '1': 'Australia',
#   '2': 'India',
#   '3': 'India',
#   '4': 'England',
#   '5': 'Australia',
#   '6': 'Afghanistan',
#   '7': 'New Zealand',
#   '8': 'England',
#   '9': 'Afghanistan',
#   '10': 'Bangladesh',
#   '11': 'India',
#   '12': 'Australia',
#   '13': 'New Zealand',
#   '14': 'Afghanistan',
#   '15': 'India',
#   '16': 'New Zealand',
#   '17': 'Bangladesh',
#   '18': 'Afghanistan',
#   '19': 'India',
#   '20': 'Bangladesh',
#   '21': 'Australia',
#   '22': 'Pakistan',
#   '23': 'England',
#   '24': 'Australia',
#   '25': 'Bangladesh',
#   '26': 'Afghanistan',
#   '27': 'India',
#   '28': 'England',
#   '29': 'Netherlands',
#   '30': 'Australia',
#   '31': 'India',
#   '32': 'Afghanistan',
#   '33': 'Netherlands',
#   '34': 'Australia',
#   '35': 'Afghanistan',
#   '36': 'India',
#   '37': 'Bangladesh',
#   '38': 'Australia',
#   '39': 'India',
#   '40': 'Pakistan',
#   '41': 'Bangladesh',
#   '42': 'Netherlands',
#   '43': 'India',
#   '44': 'South Africa',
#   '45': 'Afghanistan',
#   '46': 'Netherlands',
#   '47': 'England'},
#  'Team 2': {'0': 'Australia',
#   '1': 'South Africa',
#   '2': 'New Zealand',
#   '3': 'Netherlands',
#   '4': 'Pakistan',
#   '5': 'Bangladesh',
#   '6': 'South Africa',
#   '7': 'Sri Lanka',
#   '8': 'Netherlands',
#   '9': 'Australia',
#   '10': 'Sri Lanka',
#   '11': 'South Africa',
#   '12': 'England',
#   '13': 'Pakistan',
#   '14': 'Netherlands',
#   '15': 'Sri Lanka',
#   '16': 'South Africa',
#   '17': 'Pakistan',
#   '18': 'Sri Lanka',
#   '19': 'England',
#   '20': 'Netherlands',
#   '21': 'New Zealand',
#   '22': 'South Africa',
#   '23': 'Sri Lanka',
#   '24': 'Netherlands',
#   '25': 'South Africa',
#   '26': 'Pakistan',
#   '27': 'New Zealand',
#   '28': 'South Africa',
#   '29': 'Sri Lanka',
#   '30': 'Pakistan',
#   '31': 'Bangladesh',
#   '32': 'New Zealand',
#   '33': 'South Africa',
#   '34': 'Sri Lanka',
#   '35': 'England',
#   '36': 'Pakistan',
#   '37': 'New Zealand',
#   '38': 'South Africa',
#   '39': 'Afghanistan',
#   '40': 'Sri Lanka',
#   '41': 'England',
#   '42': 'New Zealand',
#   '43': 'Australia',
#   '44': 'Sri Lanka',
#   '45': 'Bangladesh',
#   '46': 'Pakistan',
#   '47': 'New Zealand'},
#  'match': {'0': 'India vs Australia',
#   '1': 'Australia vs South Africa',
#   '2': 'India vs New Zealand',
#   '3': 'India vs Netherlands',
#   '4': 'England vs Pakistan',
#   '5': 'Australia vs Bangladesh',
#   '6': 'Afghanistan vs South Africa',
#   '7': 'New Zealand vs Sri Lanka',
#   '8': 'England vs Netherlands',
#   '9': 'Afghanistan vs Australia',
#   '10': 'Bangladesh vs Sri Lanka',
#   '11': 'India vs South Africa',
#   '12': 'Australia vs England',
#   '13': 'New Zealand vs Pakistan',
#   '14': 'Afghanistan vs Netherlands',
#   '15': 'India vs Sri Lanka',
#   '16': 'New Zealand vs South Africa',
#   '17': 'Bangladesh vs Pakistan',
#   '18': 'Afghanistan vs Sri Lanka',
#   '19': 'India vs England',
#   '20': 'Bangladesh vs Netherlands',
#   '21': 'Australia vs New Zealand',
#   '22': 'Pakistan vs South Africa',
#   '23': 'England vs Sri Lanka',
#   '24': 'Australia vs Netherlands',
#   '25': 'Bangladesh vs South Africa',
#   '26': 'Afghanistan vs Pakistan',
#   '27': 'India vs New Zealand',
#   '28': 'England vs South Africa',
#   '29': 'Netherlands vs Sri Lanka',
#   '30': 'Australia vs Pakistan',
#   '31': 'India vs Bangladesh',
#   '32': 'Afghanistan vs New Zealand',
#   '33': 'Netherlands vs South Africa',
#   '34': 'Australia vs Sri Lanka',
#   '35': 'Afghanistan vs England',
#   '36': 'India vs Pakistan',
#   '37': 'Bangladesh vs New Zealand',
#   '38': 'Australia vs South Africa',
#   '39': 'India vs Afghanistan',
#   '40': 'Pakistan vs Sri Lanka',
#   '41': 'Bangladesh vs England',
#   '42': 'Netherlands vs New Zealand',
#   '43': 'India vs Australia',
#   '44': 'South Africa vs Sri Lanka',
#   '45': 'Afghanistan vs Bangladesh',
#   '46': 'Netherlands vs Pakistan',
#   '47': 'England vs New Zealand'},
#  'Winner': {'0': 'Australia',
#   '1': 'Australia',
#   '2': 'India',
#   '3': 'India',
#   '4': 'England',
#   '5': 'Australia',
#   '6': 'South Africa',
#   '7': 'New Zealand',
#   '8': 'England',
#   '9': 'Australia',
#   '10': 'Bangladesh',
#   '11': 'India',
#   '12': 'Australia',
#   '13': 'Pakistan',
#   '14': 'Afghanistan',
#   '15': 'India',
#   '16': 'South Africa',
#   '17': 'Pakistan',
#   '18': 'Afghanistan',
#   '19': 'India',
#   '20': 'Netherlands',
#   '21': 'Australia',
#   '22': 'South Africa',
#   '23': 'Sri Lanka',
#   '24': 'Australia',
#   '25': 'South Africa',
#   '26': 'Afghanistan',
#   '27': 'India',
#   '28': 'South Africa',
#   '29': 'Sri Lanka',
#   '30': 'Australia',
#   '31': 'India',
#   '32': 'New Zealand',
#   '33': 'Netherlands',
#   '34': 'Australia',
#   '35': 'Afghanistan',
#   '36': 'India',
#   '37': 'New Zealand',
#   '38': 'South Africa',
#   '39': 'India',
#   '40': 'Pakistan',
#   '41': 'England',
#   '42': 'New Zealand',
#   '43': 'India',
#   '44': 'South Africa',
#   '45': 'Bangladesh',
#   '46': 'Pakistan',
#   '47': 'New Zealand'},
#  'Margin': {'0': '6 wickets',
#   '1': '3 wickets',
#   '2': '70 runs',
#   '3': '160 runs',
#   '4': '93 runs',
#   '5': '8 wickets',
#   '6': '5 wickets',
#   '7': '5 wickets',
#   '8': '160 runs',
#   '9': '3 wickets',
#   '10': '3 wickets',
#   '11': '243 runs',
#   '12': '33 runs',
#   '13': '21 runs',
#   '14': '7 wickets',
#   '15': '302 runs',
#   '16': '190 runs',
#   '17': '7 wickets',
#   '18': '7 wickets',
#   '19': '100 runs',
#   '20': '87 runs',
#   '21': '5 runs',
#   '22': '1 wicket',
#   '23': '8 wickets',
#   '24': '309 runs',
#   '25': '149 runs',
#   '26': '8 wickets',
#   '27': '4 wickets',
#   '28': '229 runs',
#   '29': '5 wickets',
#   '30': '62 runs',
#   '31': '7 wickets',
#   '32': '149 runs',
#   '33': '38 runs',
#   '34': '5 wickets',
#   '35': '69 runs',
#   '36': '7 wickets',
#   '37': '8 wickets',
#   '38': '134 runs',
#   '39': '8 wickets',
#   '40': '6 wickets',
#   '41': '137 runs',
#   '42': '99 runs',
#   '43': '6 wickets',
#   '44': '102 runs',
#   '45': '6 wickets',
#   '46': '81 runs',
#   '47': '9 wickets'},
#  'Ground': {'0': 'Ahmedabad',
#   '1': 'Eden Gardens',
#   '2': 'Wankhede',
#   '3': 'Bengaluru',
#   '4': 'Eden Gardens',
#   '5': 'Pune',
#   '6': 'Ahmedabad',
#   '7': 'Bengaluru',
#   '8': 'Pune',
#   '9': 'Wankhede',
#   '10': 'Delhi',
#   '11': 'Eden Gardens',
#   '12': 'Ahmedabad',
#   '13': 'Bengaluru',
#   '14': 'Lucknow',
#   '15': 'Wankhede',
#   '16': 'Pune',
#   '17': 'Eden Gardens',
#   '18': 'Pune',
#   '19': 'Lucknow',
#   '20': 'Eden Gardens',
#   '21': 'Dharamsala',
#   '22': 'Chennai',
#   '23': 'Bengaluru',
#   '24': 'Delhi',
#   '25': 'Wankhede',
#   '26': 'Chennai',
#   '27': 'Dharamsala',
#   '28': 'Wankhede',
#   '29': 'Lucknow',
#   '30': 'Bengaluru',
#   '31': 'Pune',
#   '32': 'Chennai',
#   '33': 'Dharamsala',
#   '34': 'Lucknow',
#   '35': 'Delhi',
#   '36': 'Ahmedabad',
#   '37': 'Chennai',
#   '38': 'Lucknow',
#   '39': 'Delhi',
#   '40': 'Hyderabad',
#   '41': 'Dharamsala',
#   '42': 'Hyderabad',
#   '43': 'Chennai',
#   '44': 'Delhi',
#   '45': 'Dharamsala',
#   '46': 'Hyderabad',
#   '47': 'Ahmedabad'},
#  'Match Date': {'0': 'Nov 19, 2023',
#   '1': 'Nov 16, 2023',
#   '2': 'Nov 15, 2023',
#   '3': 'Nov 12, 2023',
#   '4': 'Nov 11, 2023',
#   '5': 'Nov 11, 2023',
#   '6': 'Nov 10, 2023',
#   '7': 'Nov 9, 2023',
#   '8': 'Nov 8, 2023',
#   '9': 'Nov 7, 2023',
#   '10': 'Nov 6, 2023',
#   '11': 'Nov 5, 2023',
#   '12': 'Nov 4, 2023',
#   '13': 'Nov 4, 2023',
#   '14': 'Nov 3, 2023',
#   '15': 'Nov 2, 2023',
#   '16': 'Nov 1, 2023',
#   '17': 'Oct 31, 2023',
#   '18': 'Oct 30, 2023',
#   '19': 'Oct 29, 2023',
#   '20': 'Oct 28, 2023',
#   '21': 'Oct 28, 2023',
#   '22': 'Oct 27, 2023',
#   '23': 'Oct 26, 2023',
#   '24': 'Oct 25, 2023',
#   '25': 'Oct 24, 2023',
#   '26': 'Oct 23, 2023',
#   '27': 'Oct 22, 2023',
#   '28': 'Oct 21, 2023',
#   '29': 'Oct 21, 2023',
#   '30': 'Oct 20, 2023',
#   '31': 'Oct 19, 2023',
#   '32': 'Oct 18, 2023',
#   '33': 'Oct 17, 2023',
#   '34': 'Oct 16, 2023',
#   '35': 'Oct 15, 2023',
#   '36': 'Oct 14, 2023',
#   '37': 'Oct 13, 2023',
#   '38': 'Oct 12, 2023',
#   '39': 'Oct 11, 2023',
#   '40': 'Oct 10, 2023',
#   '41': 'Oct 10, 2023',
#   '42': 'Oct 9, 2023',
#   '43': 'Oct 8, 2023',
#   '44': 'Oct 7, 2023',
#   '45': 'Oct 7, 2023',
#   '46': 'Oct 6, 2023',
#   '47': 'Oct 5, 2023'},
#  'Scorecard': {'0': 'ODI # 4705',
#   '1': 'ODI # 4704',
#   '2': 'ODI # 4703',
#   '3': 'ODI # 4702',
#   '4': 'ODI # 4701',
#   '5': 'ODI # 4700',
#   '6': 'ODI # 4699',
#   '7': 'ODI # 4698',
#   '8': 'ODI # 4697',
#   '9': 'ODI # 4696',
#   '10': 'ODI # 4695',
#   '11': 'ODI # 4694',
#   '12': 'ODI # 4693',
#   '13': 'ODI # 4692',
#   '14': 'ODI # 4691',
#   '15': 'ODI # 4690',
#   '16': 'ODI # 4689',
#   '17': 'ODI # 4688',
#   '18': 'ODI # 4687',
#   '19': 'ODI # 4686',
#   '20': 'ODI # 4685',
#   '21': 'ODI # 4684',
#   '22': 'ODI # 4683',
#   '23': 'ODI # 4682',
#   '24': 'ODI # 4681',
#   '25': 'ODI # 4680',
#   '26': 'ODI # 4679',
#   '27': 'ODI # 4678',
#   '28': 'ODI # 4677',
#   '29': 'ODI # 4676',
#   '30': 'ODI # 4675',
#   '31': 'ODI # 4674',
#   '32': 'ODI # 4673',
#   '33': 'ODI # 4672',
#   '34': 'ODI # 4671',
#   '35': 'ODI # 4670',
#   '36': 'ODI # 4669',
#   '37': 'ODI # 4668',
#   '38': 'ODI # 4667',
#   '39': 'ODI # 4666',
#   '40': 'ODI # 4665',
#   '41': 'ODI # 4664',
#   '42': 'ODI # 4663',
#   '43': 'ODI # 4662',
#   '44': 'ODI # 4661',
#   '45': 'ODI # 4660',
#   '46': 'ODI # 4659',
#   '47': 'ODI # 4658'},
#  'link': {'0': 'https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/india-vs-australia-final-1384439/full-scorecard',
#   '1': 'https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/australia-vs-south-africa-2nd-semi-final-1384438/full-scorecard',
#   '2': 'https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/india-vs-new-zealand-1st-semi-final-1384437/full-scorecard',
#   '3': 'https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/india-vs-netherlands-45th-match-1384436/full-scorecard',
#   '4': 'https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/england-vs-pakistan-44th-match-1384435/full-scorecard',
#   '5': 'https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/australia-vs-bangladesh-43rd-match-1384434/full-scorecard',
#   '6': 'https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/afghanistan-vs-south-africa-42nd-match-1384433/full-scorecard',
#   '7': 'https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/new-zealand-vs-sri-lanka-41st-match-1384432/full-scorecard',
#   '8': 'https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/england-vs-netherlands-40th-match-1384431/full-scorecard',
#   '9': 'https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/afghanistan-vs-australia-39th-match-1384430/full-scorecard',
#   '10': 'https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/bangladesh-vs-sri-lanka-38th-match-1384429/full-scorecard',
#   '11': 'https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/india-vs-south-africa-37th-match-1384428/full-scorecard',
#   '12': 'https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/australia-vs-england-36th-match-1384427/full-scorecard',
#   '13': 'https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/new-zealand-vs-pakistan-35th-match-1384426/full-scorecard',
#   '14': 'https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/afghanistan-vs-netherlands-34th-match-1384425/full-scorecard',
#   '15': 'https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/india-vs-sri-lanka-33rd-match-1384424/full-scorecard',
#   '16': 'https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/new-zealand-vs-south-africa-32nd-match-1384423/full-scorecard',
#   '17': 'https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/bangladesh-vs-pakistan-31st-match-1384422/full-scorecard',
#   '18': 'https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/afghanistan-vs-sri-lanka-30th-match-1384421/full-scorecard',
#   '19': 'https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/india-vs-england-29th-match-1384420/full-scorecard',
#   '20': 'https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/bangladesh-vs-netherlands-28th-match-1384419/full-scorecard',
#   '21': 'https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/australia-vs-new-zealand-27th-match-1384418/full-scorecard',
#   '22': 'https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/pakistan-vs-south-africa-26th-match-1384417/full-scorecard',
#   '23': 'https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/england-vs-sri-lanka-25th-match-1384416/full-scorecard',
#   '24': 'https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/australia-vs-netherlands-24th-match-1384415/full-scorecard',
#   '25': 'https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/bangladesh-vs-south-africa-23rd-match-1384414/full-scorecard',
#   '26': 'https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/afghanistan-vs-pakistan-22nd-match-1384413/full-scorecard',
#   '27': 'https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/india-vs-new-zealand-21st-match-1384412/full-scorecard',
#   '28': 'https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/england-vs-south-africa-20th-match-1384411/full-scorecard',
#   '29': 'https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/netherlands-vs-sri-lanka-19th-match-1384410/full-scorecard',
#   '30': 'https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/australia-vs-pakistan-18th-match-1384409/full-scorecard',
#   '31': 'https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/india-vs-bangladesh-17th-match-1384408/full-scorecard',
#   '32': 'https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/afghanistan-vs-new-zealand-16th-match-1384407/full-scorecard',
#   '33': 'https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/netherlands-vs-south-africa-15th-match-1384406/full-scorecard',
#   '34': 'https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/australia-vs-sri-lanka-14th-match-1384405/full-scorecard',
#   '35': 'https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/afghanistan-vs-england-13th-match-1384404/full-scorecard',
#   '36': 'https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/india-vs-pakistan-12th-match-1384403/full-scorecard',
#   '37': 'https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/bangladesh-vs-new-zealand-11th-match-1384402/full-scorecard',
#   '38': 'https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/australia-vs-south-africa-10th-match-1384401/full-scorecard',
#   '39': 'https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/india-vs-afghanistan-9th-match-1384400/full-scorecard',
#   '40': 'https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/pakistan-vs-sri-lanka-8th-match-1384399/full-scorecard',
#   '41': 'https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/bangladesh-vs-england-7th-match-1384398/full-scorecard',
#   '42': 'https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/netherlands-vs-new-zealand-6th-match-1384397/full-scorecard',
#   '43': 'https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/india-vs-australia-5th-match-1384396/full-scorecard',
#   '44': 'https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/south-africa-vs-sri-lanka-4th-match-1384395/full-scorecard',
#   '45': 'https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/afghanistan-vs-bangladesh-3rd-match-1384394/full-scorecard',
#   '46': 'https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/netherlands-vs-pakistan-2nd-match-1384393/full-scorecard',
#   '47': 'https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/england-vs-new-zealand-1st-match-1384392/full-scorecard'}}

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def scrape_table_data(url):
    response = requests.get(url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        table = soup.find_all('table')[0]

        if table:
            table_data = []
            rows = table.find_all('tr')

            for row in rows:
                cells = row.find_all(['td', 'th'])
                row_data = [cell.text.strip() for cell in cells]

                last_cell = cells[-1]
                href_value = last_cell.find('a')['href'] if last_cell.find('a') else None
                row_data.append(href_value)

                table_data.append(row_data)

            df = pd.DataFrame(table_data[1:], columns=table_data[0])
            df.rename(columns={df.columns[-1]: 'link'}, inplace=True)
            df.insert(2, 'match', df['Team 1'] + ' vs ' + df['Team 2'])
            df['link'] = 'https://www.espncricinfo.com' + df['link']

            # Save the DataFrame to a CSV file
            df.to_csv('match_info.csv', index=False)

            return df.dropna()
        else:
            print('Table not found on the page.')
            return None
    else:
        print(f'Error {response.status_code}: Failed to retrieve the page.')
        return None

# Example usage:
url = 'https://www.espncricinfo.com/records/tournament/team-match-results/icc-cricket-world-cup-2023-24-15338'
result_df = scrape_table_data(url)

# Check if DataFrame is not None and has data
if result_df is not None and not result_df.empty:
    print('match_info.csv successfully created')
else:
    print('Failed to create match_info.csv')
# Out:
# match_info.csv successfully created

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json

def scrape_additional_text(url, selector):
    response = requests.get(url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        element = soup.select_one(selector)

        if element:
            text = element.get_text(strip=True)
            return text
        else:
            print(f'Element not found with selector: {selector}')
            return None
    else:
        print(f'Error {response.status_code}: Failed to retrieve the page.')
        return None

def scrape_table_data(url, table_index):
    response = requests.get(url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        table = soup.find_all('table')[table_index]

        if table:
            table_data = []
            rows = table.find_all('tr')

            for row in rows:
                cells = row.find_all(['td', 'th'])
                row_data = [cell.text.strip() for cell in cells]
                table_data.append(row_data)

            df = pd.DataFrame(table_data[1:], columns=table_data[0])
            df.rename(columns={df.columns[1]: 'bowler'}, inplace=True)

            return df.dropna()
            
        else:
            print('Table not found on the page.')
            return None
    else:
        print(f'Error {response.status_code}: Failed to retrieve the page.')
        return None

def process_urls_from_json(json_filename):
    with open(json_filename, 'r') as json_file:
        data = pd.read_json(json_file, orient='records')

    output_list = []

    for index, row in data.iterrows():
        url = row['link']
        match_value = row['match']

        selector = ".ds-text-title-xs.ds-font-bold.ds-capitalize"
        additional_text = scrape_additional_text(url, selector)


        table_index = 0 if index % 2 == 0 else 2
        result_df = scrape_table_data(url, table_index)

        if result_df is not None:
            result_df.insert(0, 'match', match_value)
            result_df.insert(2, 'BattingPos', range(1, len(result_df) + 1))
            result_df.insert(1, 'teamInnings', additional_text)

            output_list.extend(result_df.dropna().to_dict(orient='records'))

    with open('batting_info.json', 'w') as json_output_file:
        json.dump(output_list, json_output_file, indent=2)

json_filename = 'match_info.json'
process_urls_from_json(json_filename)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json

def scrape_additional_text(url, selector):
    response = requests.get(url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        element = soup.select_one(selector)

        if element:
            text = element.get_text(strip=True)
            return text
        else:
            print(f'Element not found with selector: {selector}')
            return None
    else:
        print(f'Error {response.status_code}: Failed to retrieve the page.')
        return None

def scrape_table_data(url, table_index):
    response = requests.get(url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        table = soup.find_all('table')[table_index]

        if table:
            table_data = []
            rows = table.find_all('tr')

            for row in rows:
                cells = row.find_all(['td', 'th'])
                row_data = [cell.text.strip() for cell in cells]
                table_data.append(row_data)

            df = pd.DataFrame(table_data[1:], columns=table_data[0])
            df.rename(columns={df.columns[1]: 'bowler'}, inplace=True)

            return df.dropna()
            
        else:
            print('Table not found on the page.')
            return None
    else:
        print(f'Error {response.status_code}: Failed to retrieve the page.')
        return None

def process_urls_from_json(json_filename):
    with open(json_filename, 'r') as json_file:
        data = pd.read_json(json_file, orient='records')

    output_list = []

    for index, row in data.iterrows():
        url = row['link']
        match_value = row['match']

        selector1 = "#main-container > div.ds-relative > div.lg\:ds-container.lg\:ds-mx-auto.lg\:ds-px-5.lg\:ds-pt-4 > div > div.ds-flex.ds-space-x-5 > div.ds-grow > div.ds-mt-3 > div:nth-child(1) > div:nth-child(2) > div > div.ds-flex.ds-px-4.ds-border-b.ds-border-line.ds-py-3.ds-bg-ui-fill-translucent-hover > div > span > span.ds-text-title-xs.ds-font-bold.ds-capitalize"
        selector2 = "#main-container > div.ds-relative > div.lg\:ds-container.lg\:ds-mx-auto.lg\:ds-px-5.lg\:ds-pt-4 > div > div.ds-flex.ds-space-x-5 > div.ds-grow > div.ds-mt-3 > div:nth-child(1) > div:nth-child(3) > div > div.ds-flex.ds-px-4.ds-border-b.ds-border-line.ds-py-3.ds-bg-ui-fill-translucent-hover > div > span > span.ds-text-title-xs.ds-font-bold.ds-capitalize"

        selector = selector1 if index % 2 == 0 else selector2
        additional_text = scrape_additional_text(url, selector)

        table_index = 0 if index % 2 == 0 else 2
        result_df = scrape_table_data(url, table_index)

        if result_df is not None:
            result_df.insert(0, 'match', match_value)
            result_df.insert(2, 'BattingPos', range(1, len(result_df) + 1))
            result_df.insert(1, 'teamInnings', additional_text)

            output_list.extend(result_df.dropna().to_dict(orient='records'))

    with open('batting_info.json', 'w') as json_output_file:
        json.dump(output_list, json_output_file, indent=2)

json_filename = 'match_info.json'
process_urls_from_json(json_filename)
# Out:
# <>:61: SyntaxWarning: invalid escape sequence '\:'
# <>:62: SyntaxWarning: invalid escape sequence '\:'
# <>:61: SyntaxWarning: invalid escape sequence '\:'
# <>:62: SyntaxWarning: invalid escape sequence '\:'
# C:\Users\DELL\AppData\Local\Temp\ipykernel_5104\1633533536.py:61: SyntaxWarning: invalid escape sequence '\:'
#   selector1 = "#main-container > div.ds-relative > div.lg\:ds-container.lg\:ds-mx-auto.lg\:ds-px-5.lg\:ds-pt-4 > div > div.ds-flex.ds-space-x-5 > div.ds-grow > div.ds-mt-3 > div:nth-child(1) > div:nth-child(2) > div > div.ds-flex.ds-px-4.ds-border-b.ds-border-line.ds-py-3.ds-bg-ui-fill-translucent-hover > div > span > span.ds-text-title-xs.ds-font-bold.ds-capitalize"
# C:\Users\DELL\AppData\Local\Temp\ipykernel_5104\1633533536.py:62: SyntaxWarning: invalid escape sequence '\:'
#   selector2 = "#main-container > div.ds-relative > div.lg\:ds-container.lg\:ds-mx-auto.lg\:ds-px-5.lg\:ds-pt-4 > div > div.ds-flex.ds-space-x-5 > div.ds-grow > div.ds-mt-3 > div:nth-child(1) > div:nth-child(3) > div > div.ds-flex.ds-px-4.ds-border-b.ds-border-line.ds-py-3.ds-bg-ui-fill-translucent-hover > div > span > span.ds-text-title-xs.ds-font-bold.ds-capitalize"

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json

def scrape_additional_text(url, selector):
    response = requests.get(url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        element = soup.select_one(selector)

        if element:
            text = element.get_text(strip=True)
            return text
        else:
            print(f'Element not found with selector: {selector}')
            return None
    else:
        print(f'Error {response.status_code}: Failed to retrieve the page.')
        return None

def scrape_table_data(url, table_index):
    response = requests.get(url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        table = soup.find_all('table')[table_index]

        if table:
            table_data = []
            rows = table.find_all('tr')

            for row in rows:
                cells = row.find_all(['td', 'th'])
                row_data = [cell.text.strip() for cell in cells]
                table_data.append(row_data)

            df = pd.DataFrame(table_data[1:], columns=table_data[0])
            df.rename(columns={df.columns[1]: 'bowler'}, inplace=True)

            return df.dropna()
        else:
            print('Table not found on the page.')
            return None
    else:
        print(f'Error {response.status_code}: Failed to retrieve the page.')
        return None

def process_urls_from_json(batting):
    with open(batting, 'r') as json_file:
        data = pd.read_json(batting, orient='records')

    output_list = []
    for index, row in data.iterrows():
        url = row['link']
        match_value = row['match']

        selector = "#main-container > div.ds-relative > div.lg\:ds-container.lg\:ds-mx-auto.lg\:ds-px-5.lg\:ds-pt-4 > div > div.ds-flex.ds-space-x-5 > div.ds-grow > div.ds-mt-3 > div:nth-child(1) > div:nth-child(2) > div > div.ds-flex.ds-px-4.ds-border-b.ds-border-line.ds-py-3.ds-bg-ui-fill-translucent-hover > div > span > span.ds-text-title-xs.ds-font-bold.ds-capitalize"
        additional_text = scrape_additional_text(url, selector)
        result_df = scrape_table_data(url, 0)

        if result_df is not None:
            result_df.insert(0, 'match', match_value)
            result_df.insert(2, 'BattingPos', range(1, len(result_df) + 1))
            result_df.insert(1, 'teamInnings', additional_text)
            output_list.extend(result_df.dropna().to_dict(orient='records'))

    with open('batting_info.json', 'w') as json_output_file:
        json.dump(output_list, json_output_file, indent=2)

    for index, row in data.iterrows():
        url = row['link']
        match_value = row['match']
        selector = "#main-container > div.ds-relative > div.lg\:ds-container.lg\:ds-mx-auto.lg\:ds-px-5.lg\:ds-pt-4 > div > div.ds-flex.ds-space-x-5 > div.ds-grow > div.ds-mt-3 > div:nth-child(1) > div:nth-child(3) > div > div.ds-flex.ds-px-4.ds-border-b.ds-border-line.ds-py-3.ds-bg-ui-fill-translucent-hover > div > span > span.ds-text-title-xs.ds-font-bold.ds-capitalize"
        additional_text = scrape_additional_text(url, selector)
        result_df = scrape_table_data(url, 2)

        if result_df is not None:
            result_df.insert(0, 'match', match_value)
            result_df.insert(2, 'BattingPos', range(1, len(result_df) + 1))
            result_df.insert(1, 'teamInnings', additional_text)
            output_list.extend(result_df.dropna().to_dict(orient='records'))

    with open('batting_info.json', 'w') as json_output_file:
        json.dump(output_list, json_output_file, indent=2)

# Example usage:
json_filename = 'match_info.json'
process_urls_from_json(json_filename)
# Out:
# <>:59: SyntaxWarning: invalid escape sequence '\:'
# <>:75: SyntaxWarning: invalid escape sequence '\:'
# <>:59: SyntaxWarning: invalid escape sequence '\:'
# <>:75: SyntaxWarning: invalid escape sequence '\:'
# C:\Users\DELL\AppData\Local\Temp\ipykernel_5104\1862137000.py:59: SyntaxWarning: invalid escape sequence '\:'
#   selector = "#main-container > div.ds-relative > div.lg\:ds-container.lg\:ds-mx-auto.lg\:ds-px-5.lg\:ds-pt-4 > div > div.ds-flex.ds-space-x-5 > div.ds-grow > div.ds-mt-3 > div:nth-child(1) > div:nth-child(2) > div > div.ds-flex.ds-px-4.ds-border-b.ds-border-line.ds-py-3.ds-bg-ui-fill-translucent-hover > div > span > span.ds-text-title-xs.ds-font-bold.ds-capitalize"
# C:\Users\DELL\AppData\Local\Temp\ipykernel_5104\1862137000.py:75: SyntaxWarning: invalid escape sequence '\:'
#   selector = "#main-container > div.ds-relative > div.lg\:ds-container.lg\:ds-mx-auto.lg\:ds-px-5.lg\:ds-pt-4 > div > div.ds-flex.ds-space-x-5 > div.ds-grow > div.ds-mt-3 > div:nth-child(1) > div:nth-child(3) > div > div.ds-flex.ds-px-4.ds-border-b.ds-border-line.ds-py-3.ds-bg-ui-fill-translucent-hover > div > span > span.ds-text-title-xs.ds-font-bold.ds-capitalize"

# %%
import numpy as np
import pandas as pd
from yaml import safe_load
import os
from tqdm import tqdm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[31], line 5
#       3 from yaml import safe_load
#       4 import os
# ----> 5 from tqdm import tqdm
#
# ModuleNotFoundError: No module named 'tqdm'
